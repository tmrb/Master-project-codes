# %% [markdown]
# <a href="https://colab.research.google.com/github/tmrb/Master-project-codes/blob/main/quali_prop_metalizadora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import sys
drive.mount("/content/drive", force_remount=True)
root  = '/content/drive/My Drive/banco_de_dados'
sys.path.append(root)
# Out:
# Mounted at /content/drive

# %%
import pandas as pandas
import numpy as numpy
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# importar a base e colocar os nomes das colunas

quali_metalizadora = pandas.read_csv('/content/drive/My Drive/banco_de_dados/dados_compilados/quali_metalizadora_geral.csv',encoding='ISO-8859-1',error_bad_lines=False,sep = ';')
prop_metalizadora = pandas.read_csv('/content/drive/My Drive/banco_de_dados/dados_compilados/prop_metalizadora_geral.csv', encoding='ISO-8859-1',error_bad_lines=False,sep = ';')

# %%
quali_metalizadora
# Out:
#       Análise  ... 115 - Arranque 7 dias 100 ciclos
# 0       59217  ...                              NaN
# 1       59219  ...                              NaN
# 2       59234  ...                              NaN
# 3       59235  ...                              NaN
# 4       59242  ...                              NaN
# ...       ...  ...                              ...
# 1540    66715  ...                              NaN
# 1541    66716  ...                              NaN
# 1542    66718  ...                              NaN
# 1543    66723  ...                              NaN
# 1544    66724  ...                              NaN
#
# [1545 rows x 123 columns]

# %%
prop_metalizadora
# Out:
#         Bobina  Campanha    Máquina  ... Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0     H17365273    12MIC  METALIZA2  ...         NaN         NaN         NaN
# 1     H17365274     12MQ  METALIZA2  ...         NaN         NaN         NaN
# 2     H17365275    12MIC  METALIZA2  ...         NaN         NaN         NaN
# 3     H18001276   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 4     H18001277   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# ...         ...      ...        ...  ...         ...         ...         ...
# 7912  H20236597   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 7913  H20236598   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 7914  H20236599   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 7915  H20236600   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 7916  H20236601   12M2BR  METALIZA2  ...         NaN         NaN         NaN
#
# [7917 rows x 28 columns]

# %%
prop_metalizadora
# Out:
#         Bobina  Campanha    Máquina  ... Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0     H17365273    12MIC  METALIZA2  ...         NaN         NaN         NaN
# 1     H17365274     12MQ  METALIZA2  ...         NaN         NaN         NaN
# 2     H17365275    12MIC  METALIZA2  ...         NaN         NaN         NaN
# 3     H18001276   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 4     H18001277   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# ...         ...      ...        ...  ...         ...         ...         ...
# 7912  H20236597   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 7913  H20236598   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 7914  H20236599   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 7915  H20236600   12M2BR  METALIZA2  ...         NaN         NaN         NaN
# 7916  H20236601   12M2BR  METALIZA2  ...         NaN         NaN         NaN
#
# [7917 rows x 28 columns]

# %%
quali_prop_metalizadora = pandas.DataFrame()
quali_prop_metalizadora = quali_metalizadora.merge(prop_metalizadora, left_on = 'Lote', right_on='Bobina ')
quali_prop_metalizadora = quali_prop_metalizadora.drop(columns=['Unnamed: 25','Unnamed: 26','Unnamed: 27'])
quali_prop_metalizadora
# Out:
#       Análise        Data Campanha_x  ...  D.O. 9   D.O. 10   D.O. 11
# 0       59234  22/07/2019      12MZ2  ...     2,41      2,41       2,4
# 1       59234  22/07/2019      12MZ2  ...    2,41      2,41      2,40
# 2       59235  22/07/2019     12QMIC  ...     2,42      2,43       2,4
# 3       59235  22/07/2019     12QMIC  ...    2,42      2,43      2,40
# 4       59242  23/07/2019     12QMIC  ...     2,41       2,4      2,41
# ...       ...         ...        ...  ...      ...       ...       ...
# 1884    66715  21/08/2020     12M2BR  ...    3,35      3,40      3,40
# 1885    66716  22/08/2020       12MZ  ...    2,38      2,39      2,40
# 1886    66718  21/08/2020       10MZ  ...    2,39      2,39      2,38
# 1887    66723  23/08/2020     12M2BR  ...    3,41      3,42      3,40
# 1888    66724  23/08/2020     12M2BR  ...    3,41      3,42      3,41
#
# [1889 rows x 148 columns]

# %%
quali_prop_metalizadora.dropna(axis = 1, how = 'all')
# Out:
#       Análise        Data Campanha_x  ...  D.O. 9   D.O. 10   D.O. 11
# 0       59234  22/07/2019      12MZ2  ...     2,41      2,41       2,4
# 1       59234  22/07/2019      12MZ2  ...    2,41      2,41      2,40
# 2       59235  22/07/2019     12QMIC  ...     2,42      2,43       2,4
# 3       59235  22/07/2019     12QMIC  ...    2,42      2,43      2,40
# 4       59242  23/07/2019     12QMIC  ...     2,41       2,4      2,41
# ...       ...         ...        ...  ...      ...       ...       ...
# 1884    66715  21/08/2020     12M2BR  ...    3,35      3,40      3,40
# 1885    66716  22/08/2020       12MZ  ...    2,38      2,39      2,40
# 1886    66718  21/08/2020       10MZ  ...    2,39      2,39      2,38
# 1887    66723  23/08/2020     12M2BR  ...    3,41      3,42      3,40
# 1888    66724  23/08/2020     12M2BR  ...    3,41      3,42      3,41
#
# [1889 rows x 42 columns]

# %%
result = pandas.DataFrame()
result = pandas.DataFrame.dropna(quali_prop_metalizadora,subset=['Situação'])

# %%
result
# Out:
#       Análise        Data Campanha_x  ...  D.O. 9   D.O. 10   D.O. 11
# 0       59234  22/07/2019      12MZ2  ...     2,41      2,41       2,4
# 1       59234  22/07/2019      12MZ2  ...    2,41      2,41      2,40
# 2       59235  22/07/2019     12QMIC  ...     2,42      2,43       2,4
# 3       59235  22/07/2019     12QMIC  ...    2,42      2,43      2,40
# 4       59242  23/07/2019     12QMIC  ...     2,41       2,4      2,41
# ...       ...         ...        ...  ...      ...       ...       ...
# 1884    66715  21/08/2020     12M2BR  ...    3,35      3,40      3,40
# 1885    66716  22/08/2020       12MZ  ...    2,38      2,39      2,40
# 1886    66718  21/08/2020       10MZ  ...    2,39      2,39      2,38
# 1887    66723  23/08/2020     12M2BR  ...    3,41      3,42      3,40
# 1888    66724  23/08/2020     12M2BR  ...    3,41      3,42      3,41
#
# [1889 rows x 148 columns]

# %%
result.to_csv(r'C:\Users\Thiago\Desktop\Artigos\Projeto\quali_prop_metalizadora.csv', index=False)

# %%
# Import Drive API and authenticate.
from google.colab import drive

# Mount your Drive to the Colab VM.
drive.mount('/gdrive')

# Write the DataFrame to CSV file.
with open('/gdrive/My Drive/banco_de_dados/quali_prop_metalizadora.csv', 'w') as f:
  result.to_csv(f)
# Out:
# Mounted at /gdrive
